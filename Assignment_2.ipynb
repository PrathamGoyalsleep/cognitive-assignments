# %% [markdown]
# Q1

# %%
rollNo=1024170233
my_list=[]
for digit in str(rollNo):
  x=int(digit)
  x*=10
  my_list.append(x)
print(my_list)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 30, 30]

# %%
my_list.append(80)
my_list
my_list.insert(3,85)
my_list
# Out:
# [10, 0, 20, 85, 40, 10, 70, 0, 20, 30, 30, 80]

# %%
my_list.remove(10)
my_list #10 at index 0 (first occurrence) has been removed
my_list.pop(3) #40
# Out:
# 40

# %%
my_list.sort()
my_list
# Out:
# [0, 0, 20, 30, 70, 80, 85, 90]

# %%
my_list.sort(reverse=True)
my_list
# Out:
# [90, 85, 80, 70, 30, 20, 0, 0]

# %%
my_list[:4]
my_list
my_list[4:]
my_list
# Out:
# [90, 85, 80, 70, 30, 20, 0, 0]

# %%
new_list=[]
average=sum(my_list)/len(my_list)
for i in my_list:
  if i>average:
    new_list.append(i)
print(new_list)
# Out:
# [90, 85, 80, 70]

# %% [markdown]
# Q2

# %%
scores=(10,0,20,40,10,70,0,30)
highest=max(scores)
print(highest)
print(scores.index(highest))
lowest=min(scores)
print(lowest)
print(scores.count(lowest))
# Out:
# 70
# 5
# 0
# 2

# %%
import builtins
rev_scores=builtins.list(scores[::-1])
print(rev_scores)
# Out:
# [30, 0, 70, 10, 40, 20, 0, 10]

# %%
score=int(input("Enter a score:"))
if score in scores:
  print(scores.index(score))
else:
  print("Not presesnt")
# Out:
# Enter a score:90
# Not presesnt

# %% [markdown]
# Q3

# %% [markdown]
# (i)

# %%
import random

random.seed(1024170233)

numbers = [random.randint(100, 900) for _ in range(100)]

print("List of 100 random numbers:")
print(numbers)
# Out:
# List of 100 random numbers:
# [755, 830, 591, 842, 421, 316, 155, 216, 763, 737, 452, 678, 119, 887, 822, 364, 205, 602, 566, 786, 531, 469, 136, 429, 647, 821, 582, 202, 884, 319, 280, 330, 599, 649, 417, 732, 275, 863, 259, 680, 138, 231, 207, 845, 727, 594, 771, 229, 402, 873, 392, 693, 624, 611, 201, 744, 441, 645, 188, 647, 250, 352, 744, 694, 656, 629, 441, 189, 235, 373, 208, 615, 656, 205, 790, 439, 742, 444, 360, 669, 692, 282, 786, 186, 113, 308, 313, 398, 608, 295, 639, 492, 390, 258, 826, 214, 308, 501, 235, 595]

# %% [markdown]
# (ii)

# %%
odd_numbers = [num for num in numbers if num % 2 != 0]

print("\nOdd numbers:")
print(odd_numbers)
print("Count of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers:
# [287, 677, 833, 319, 849, 139, 327, 739, 541, 337, 193, 807, 299, 503, 191, 521, 605, 283, 173, 835, 241, 497, 527, 357, 625, 471, 347, 249, 601, 501, 187, 197, 481, 571, 803, 565, 535, 713, 323, 395, 175, 713, 891, 413, 809, 639, 425]
# Count of odd numbers: 47

# %% [markdown]
# (iii)

# %%
even_numbers = [num for num in numbers if num % 2 == 0]

print("\nEven numbers:")
print(even_numbers)
print("Count of even numbers:", len(even_numbers))

def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True
# Out:
# Even numbers:
# [226, 270, 812, 630, 468, 410, 260, 552, 244, 478, 760, 564, 626, 232, 680, 462, 828, 622, 516, 894, 654, 732, 846, 750, 782, 466, 534, 814, 456, 540, 762, 504, 488, 582, 490, 128, 676, 664, 108, 724, 444, 646, 634, 258, 518, 836, 688, 438, 730, 476, 146, 444, 520]
# Count of even numbers: 53

# %% [markdown]
# (iv)

# %%
prime_numbers = [num for num in numbers if is_prime(num)]

print("\nPrime numbers:")
print(prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers:
# [677, 139, 739, 541, 337, 193, 503, 191, 521, 283, 173, 241, 347, 601, 197, 571, 809]
# Count of prime numbers: 17

# %% [markdown]
# (v)

# %%
most_frequent = max(numbers, key=numbers.count)
frequency = numbers.count(most_frequent)

print("\nMost frequent number:", most_frequent)
print("Number of times it occurs:", frequency)
# Out:
# Most frequent number: 444
# Number of times it occurs: 2

# %% [markdown]
# Q4

# %% [markdown]
# (vi)

# %%
digits = [1, 0, 2, 4, 1, 7, 0, 2]


A = {digit * 7 for digit in digits}

B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)

union_set = A.union(B)
print("\nUnion of A and B:", union_set)
# Out:
# Set A: {0, 7, 14, 49, 28}
# Set B: {0, 36, 9, 18, 63}
#
# Union of A and B: {0, 36, 7, 9, 14, 49, 18, 28, 63}

# %% [markdown]
# (vii,viii)

# %%
intersection_set = A.intersection(B)
print("\nIntersection of A and B:", intersection_set)

A_minus_B = A.difference(B)
B_minus_A = B.difference(A)

print("\nA - B:", A_minus_B)
print("B - A:", B_minus_A)

# %% [markdown]
# (ix,x,xi)

# %%
symmetric_diff = A.symmetric_difference(B)
print("\nSymmetric Difference:", symmetric_diff)

print("\nIs A a subset of B?", A.issubset(B))
print("Is B a superset of A?", B.issuperset(A))

X = int(input("\nEnter a value to remove from Set A: "))

A.discard(X)

print("Set A after discard():", A)
